# %%
from nltk import PorterStemmer
from nltk.tokenize import wordpunct_tokenize
import codecs

afinn = (map(lambda (k,v):(PorterStemmer().stem(k), int(v)) ,[ line.split('\t') for line in codecs.open("/Users/ainalopez/Downloads/text_mining-master/data/AFINN/AFINN-111.txt",'r', 'utf-8') ]))

for doc in doc.corpus:
# Out:
# [(u'abandon', -2), (u'abandon', -2), (u'abandon', -2), (u'abduct', -2), (u'abduct', -2), (u'abduct', -2), (u'abhor', -3), (u'abhor', -3), (u'abhorr', -3), (u'abhor', -3), (u'abil', 2), (u'abil', 2), (u'aboard', 1), (u'absente', -1), (u'absente', -1), (u'absolv', 2), (u'absolv', 2), (u'absolv', 2), (u'absolv', 2), (u'absorb', 1), (u'abus', -3), (u'abus', -3), (u'abus', -3), (u'abus', -3), (u'accept', 1), (u'accept', 1), (u'accept', 1), (u'accept', 1), (u'accid', -2), (u'accident', -2), (u'accident', -2), (u'accid', -2), (u'accomplish', 2), (u'accomplish', 2), (u'accomplish', 2), (u'accus', -2), (u'accus', -2), (u'accus', -2), (u'accus', -2), (u'accus', -2), (u'accus', -2), (u'ach', -2), (u'achiev', 1), (u'ach', -2), (u'acquit', 2), (u'acquit', 2), (u'acquit', 2), (u'acquit', 2), (u'acrimoni', -3), (u'activ', 1), (u'adequ', 1), (u'admir', 3), (u'admir', 3), (u'admir', 3), (u'admir', 3), (u'admit', -1), (u'admit', -1), (u'admit', -1), (u'admonish', -2), (u'admonish', -2), (u'adopt', 1),
# ...
