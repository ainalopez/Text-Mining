# %%
from nltk import PorterStemmer


#finn = (map(lambda (k,v):(PorterStemmer().stem(k), int(v)) ,[ line.split('\t') for line in open("/Users/ainalopez/Downloads/text_mining-master/data/AFINN/AFINN-111.txt") ]))
# PorterStemmer().stem(k)
#afinn["Good".lower()]

afinn = {}
a = []
for line in open("/Users/ainalopez/Downloads/text_mining-master/data/AFINN/AFINN-111.txt"):
    print PorterStemmer().stem(line.split()[0])
#    #a = "u'"+a+"'"
#    afinn[a] = 0#line.split()[1]
#    #print PorterStemmer().stem(line.split()[0])

print a

#sum(map(lambda word: afinn.get(word, 0), "Rainy day but still in a good mood".lower().split()))
# Out:
# abandon
# abandon
# abandon
# abduct
# abduct
# abduct
# abhor
# abhor
# abhorr
# abhor
# abil
# abil
# aboard
# absente
# absente
# absolv
# absolv
# absolv
# absolv
# absorb
# abus
# abus
# abus
# abus
# accept
# accept
# accept
# accept
# accid
# accident
# accident
# accid
# accomplish
# accomplish
# accomplish
# accus
# accus
# accus
# accus
# accus
# accus
# ach
# achiev
# ach
# acquit
# acquit
# acquit
# acquit
# acrimoni
# activ
# adequ
# admir
# admir
# admir
# admir
# admit
# admit
# admit
# admonish
# admonish
# adopt
# adopt
# ador
# ador
# ador
# ador
# advanc
# advantag
# advantag
# adventur
# adventur
# adventur
# affect
# affect
# affection
# afflict
# affront
# afraid
# aggrav
# aggrav
# aggrav
# aggrav
# aggress
# aggress
# aggress
# aghast
# agog
# agonis
# agonis
# agonis
# agonis
# agon
# agon
# agon
# agon
# agre
# agreeabl
# agre
# agreement
# agre
# alarm
# alarm
# alarmist
# alarmist
# ala
# alert
# alien
# aliv
# allerg
# allow
# alon
# amaz
# amaz
# amaz
# ...
